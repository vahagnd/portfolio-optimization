# %%
# %load_ext autoreload
# %autoreload 2


import pandas as pd
import numpy as np

# %%
df_mag7_raw = pd.read_csv("../data-csv/ohlcv_adjusted_mag7.csv")

# %%
list(df_mag7_raw.iloc[0][1:].unique())[0]

# %%
stats = {
            "total_records": len(df_mag7_raw),
            "stocks": list(df_mag7_raw.iloc[0][1:].unique()),
            "date_range": {
                "start": str(df_mag7_raw.iloc[2, 0]),
                "end": str(df_mag7_raw.iloc[-1, 0]),
            },
            "memory_usage": f"{(round(df_mag7_raw.memory_usage(deep=True).sum() / 1024**2, 2).item())} mb",
        }
